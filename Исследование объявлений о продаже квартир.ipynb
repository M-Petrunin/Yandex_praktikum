# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Столбец-'last_price'" data-toc-modified-id="Столбец-'last_price'-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Столбец 'last_price'</a></span></li><li><span><a href="#Столбец-'total_area'" data-toc-modified-id="Столбец-'total_area'-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Столбец 'total_area'</a></span></li><li><span><a href="#Столбец-'rooms'" data-toc-modified-id="Столбец-'rooms'-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Столбец 'rooms'</a></span></li><li><span><a href="#Столбец-'ceiling_height'" data-toc-modified-id="Столбец-'ceiling_height'-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Столбец 'ceiling_height'</a></span></li><li><span><a href="#Столбец-'floors_total'" data-toc-modified-id="Столбец-'floors_total'-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Столбец 'floors_total'</a></span></li><li><span><a href="#Столбец-'living_area'" data-toc-modified-id="Столбец-'living_area'-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Столбец 'living_area'</a></span></li><li><span><a href="#Столбец-'floor'" data-toc-modified-id="Столбец-'floor'-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Столбец 'floor'</a></span></li><li><span><a href="#Столбец-'kitchen_area'" data-toc-modified-id="Столбец-'kitchen_area'-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Столбец 'kitchen_area'</a></span></li><li><span><a href="#Столбец-'airports_nearest'" data-toc-modified-id="Столбец-'airports_nearest'-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Столбец 'airports_nearest'</a></span></li><li><span><a href="#Столбец-'cityCenters_nearest'" data-toc-modified-id="Столбец-'cityCenters_nearest'-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Столбец 'cityCenters_nearest'</a></span></li><li><span><a href="#Столбец-'parks_around3000'" data-toc-modified-id="Столбец-'parks_around3000'-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Столбец 'parks_around3000'</a></span></li><li><span><a href="#Столбец-'parks_nearest'" data-toc-modified-id="Столбец-'parks_nearest'-2.12"><span class="toc-item-num">2.12&nbsp;&nbsp;</span>Столбец 'parks_nearest'</a></span></li><li><span><a href="#Столбец-'ponds_around3000'" data-toc-modified-id="Столбец-'ponds_around3000'-2.13"><span class="toc-item-num">2.13&nbsp;&nbsp;</span>Столбец 'ponds_around3000'</a></span></li><li><span><a href="#Столбец-'ponds_nearest'" data-toc-modified-id="Столбец-'ponds_nearest'-2.14"><span class="toc-item-num">2.14&nbsp;&nbsp;</span>Столбец 'ponds_nearest'</a></span></li><li><span><a href="#Столбец-'days_exposition'" data-toc-modified-id="Столбец-'days_exposition'-2.15"><span class="toc-item-num">2.15&nbsp;&nbsp;</span>Столбец 'days_exposition'</a></span></li><li><span><a href="#Столбец-'locality_name'" data-toc-modified-id="Столбец-'locality_name'-2.16"><span class="toc-item-num">2.16&nbsp;&nbsp;</span>Столбец 'locality_name'</a></span></li><li><span><a href="#Выводы-после-первочной-предобработки" data-toc-modified-id="Выводы-после-первочной-предобработки-2.17"><span class="toc-item-num">2.17&nbsp;&nbsp;</span>Выводы после первочной предобработки</a></span></li><li><span><a href="#Исправим-аномалии" data-toc-modified-id="Исправим-аномалии-2.18"><span class="toc-item-num">2.18&nbsp;&nbsp;</span>Исправим аномалии</a></span><ul class="toc-item"><li><span><a href="#last_price" data-toc-modified-id="last_price-2.18.1"><span class="toc-item-num">2.18.1&nbsp;&nbsp;</span>last_price</a></span></li><li><span><a href="#ceiling_height" data-toc-modified-id="ceiling_height-2.18.2"><span class="toc-item-num">2.18.2&nbsp;&nbsp;</span>ceiling_height</a></span></li><li><span><a href="#rooms" data-toc-modified-id="rooms-2.18.3"><span class="toc-item-num">2.18.3&nbsp;&nbsp;</span>rooms</a></span></li></ul></li><li><span><a href="#Удалим-строки" data-toc-modified-id="Удалим-строки-2.19"><span class="toc-item-num">2.19&nbsp;&nbsp;</span>Удалим строки</a></span></li><li><span><a href="#Заполним-пропуски" data-toc-modified-id="Заполним-пропуски-2.20"><span class="toc-item-num">2.20&nbsp;&nbsp;</span>Заполним пропуски</a></span><ul class="toc-item"><li><span><a href="#balcony" data-toc-modified-id="balcony-2.20.1"><span class="toc-item-num">2.20.1&nbsp;&nbsp;</span>balcony</a></span></li><li><span><a href="#floors_total" data-toc-modified-id="floors_total-2.20.2"><span class="toc-item-num">2.20.2&nbsp;&nbsp;</span>floors_total</a></span></li></ul></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#•----Цена-квадратного-метра" data-toc-modified-id="•----Цена-квадратного-метра-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>•    Цена квадратного метра</a></span></li><li><span><a href="#•----День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="•----День-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>•    День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#•----Этаж-квартиры;-варианты-—-первый,-последний,-другой" data-toc-modified-id="•----Этаж-квартиры;-варианты-—-первый,-последний,-другой-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>•    Этаж квартиры; варианты — первый, последний, другой</a></span></li><li><span><a href="#•----Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей" data-toc-modified-id="•----Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>•    Соотношение жилой и общей площади, а также отношение площади кухни к общей</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра" data-toc-modified-id="Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра</a></span></li><li><span><a href="#Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span><ul class="toc-item"><li><span><a href="#Зависимость-Цены-от-Площади" data-toc-modified-id="Зависимость-Цены-от-Площади-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Зависимость Цены от Площади</a></span></li><li><span><a href="#Зависимость-Цены-от-Кол-ва-комнат" data-toc-modified-id="Зависимость-Цены-от-Кол-ва-комнат-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Зависимость Цены от Кол-ва комнат</a></span></li><li><span><a href="#Зависимость-Цены-от-Удалённости-от-центра" data-toc-modified-id="Зависимость-Цены-от-Удалённости-от-центра-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Зависимость Цены от Удалённости от центра</a></span></li><li><span><a href="#Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом" data-toc-modified-id="Зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом</a></span></li><li><span><a href="#Зависимость-от-даты-размещения:-дня-недели,-месяца-и-года" data-toc-modified-id="Зависимость-от-даты-размещения:-дня-недели,-месяца-и-года-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Зависимость от даты размещения: дня недели, месяца и года</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-locality_name.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.</a></span></li><li><span><a href="#Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.</a></span></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?</a></span><ul class="toc-item"><li><span><a href="#Изучение-следующих-параметров:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Изучение-следующих-параметров:-площадь,-цена,-число-комнат,-высота-потолков.-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Изучение следующих параметров: площадь, цена, число комнат, высота потолков.</a></span></li><li><span><a href="#Выделяем-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления)-и-сравниваем-Питер-и-Центр" data-toc-modified-id="Выделяем-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления)-и-сравниваем-Питер-и-Центр-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Выделяем факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления) и сравниваем Питер и Центр</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Описание данных:
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('real_estate_data.csv', sep='\t')
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Разбиремся с каждым столбцом по отдельности:
#
# 1. Стоблец **'total_images'** - заполнены все значения (<font color='green'><b>23699 non-null<b></font>), <font color='blue'><b>Для анализа столбец не нужен<b></font>.
# 2. Стоблец **'last_price'** - заполнены все значения (<font color='green'><b>23699 non-null<b></font>), в данном столбце изменим тип с <font color='blue'><b>float64 на int.<b></font>
# 3. Стоблец **'total_area'** - заполнены все значения (<font color='green'><b>23699 non-null<b></font>), в данном столбце изменим тип с <font color='blue'><b>float64 на int.<b></font>
# 4. Стоблец **'first_day_exposition'** - заполнены все значения (<font color='green'><b>23699 non-null<b></font>), в данном столбце изменим тип с <font color='blue'><b>float64 на int.<b></font>
# 5. Стоблец **'rooms'** - заполнены все значения (<font color='green'><b>23699 non-null<b></font>), корректный столбец.
# 6. Стоблец **'ceiling_height'** - пропусков <font color='red'><b>39%<b></font> (14504 из 23699 non-null), надо будет заполнить пропуски и изменить тип с <font color='blue'><b>float64 на int.<b></font>
# 7. Стоблец **'floors_total'** - пропусков <font color='red'><b>менее 1%<b></font> (23613 из 23699 non-null), надо будет заполнить пропуски и изменить тип с <font color='blue'><b>float64 на int.<b></font>
# 8. Стоблец **'living_area'** - пропусков около <font color='red'><b>8%<b></font> (21796 из 23699 non-null), необходимо заполнить.
# 9. Стоблец **'floor'** - заполнены все значения (<font color='green'><b>23699 non-null<b></font>), корректный столбец.
# 10. Стоблец **'is_apartment'** - пропусков много <font color='red'><b>88%<b></font> (2775 из 23699 non-null), <font color='blue'><b>Для анализа столбец не нужен<b></font>.
# 11. Стоблец **'studio'** - заполнены все значения (<font color='green'><b>23699 non-null<b></font>), <font color='blue'><b>Для анализа столбец не нужен<b></font>.
# 12. Стоблец **'open_plan'** - заполнены все значения (<font color='green'><b>23699 non-null<b></font>), <font color='blue'><b>Для анализа столбец не нужен<b></font>.
# 13. Стоблец **'kitchen_area'** - пропусков около <font color='red'><b>10%<b></font> (21421 из 23699 non-null), необходимо заполнить.
# 14. Стоблец **'balcony'** - пропусков много <font color='red'><b>48%<b></font> (12180 из 23699 non-null), необходимо заполнить на 0-скорее всего что их нет.
# 15. Стоблец **'locality_name'** - пропусков <font color='red'><b>менее 1%<b></font> (23650 из 23699 non-null), удалим строки с пустыми значениями.
# 16. Стоблец **'airports_nearest'** - пропусков около <font color='red'><b>23%<b></font> (18157 из 23699 non-null), <font color='blue'><b>Для анализа столбец не нужен<b></font>
# 17. Стоблец **'cityCenters_nearest'** - пропусков около <font color='red'><b>23%<b></font> (18180 из 23699 non-null), необходимо разбираться. Также изменим тип с <font color='blue'><b>float64 на int.<b></font>
# 18. Стоблец **'parks_around3000'** - пропусков около <font color='red'><b>23%<b></font> (18181 из 23699 non-null), <font color='blue'><b>Для анализа столбец не нужен<b></font>
# 19. Стоблец **'parks_nearest'** - пропусков около <font color='red'><b>66%<b></font> (8079 из 23699 non-null), <font color='blue'><b>Для анализа столбец не нужен<b></font>
# 20. Стоблец **'ponds_around3000'** - пропусков около <font color='red'><b>23%<b></font> (18181 из 23699 non-null), <font color='blue'><b>Для анализа столбец не нужен<b></font>
# 21. Стоблец **'ponds_nearest'** - пропусков около <font color='red'><b>61%<b></font> (9110 из 23699 non-null), <font color='blue'><b>Для анализа столбец не нужен<b></font>
# 22. Стоблец **'days_exposition'** - пропусков около <font color='red'><b>13%<b></font> (20518 из 23699 non-null), необходимо разбираться. Также изменим тип с <font color='blue'><b>float64 на int.<b></font>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Напишем функцию для исследования столбцов:

# %%
def investigate_column(target_column):
    print('Количества пропущенных значений:', df[target_column].isna().sum())
    print()
    print(df[target_column].describe())
    df.boxplot(column=target_column, figsize=(3,7))

# %% [markdown]
# ### Столбец 'last_price'

# %%
# изменим тип столбца на integer

df['last_price'] = df['last_price'].astype(int)

# %% [markdown]
# Применим ислед. функцию **investigate_column**:

# %%
investigate_column(['last_price'])
# Out:
# Количества пропущенных значений: last_price    0
# dtype: int64
#
#          last_price
# count  2.369900e+04
# mean   6.541549e+06
# std    1.088701e+07
# min    1.219000e+04
# 25%    3.400000e+06
# 50%    4.650000e+06
# 75%    6.800000e+06
# max    7.630000e+08

# %% [markdown]
# ### Столбец 'total_area'

# %%
df['total_area'] = df['total_area'].astype(int)

# %%
investigate_column(['total_area'])
# Out:
# Количества пропущенных значений: total_area    0
# dtype: int64
#
#          total_area
# count  23699.000000
# mean      60.120511
# std       35.665822
# min       12.000000
# 25%       40.000000
# 50%       52.000000
# 75%       69.000000
# max      900.000000

# %% [markdown]
# ### Столбец 'rooms'

# %%
investigate_column(['rooms'])
# Out:
# Количества пропущенных значений: rooms    0
# dtype: int64
#
#               rooms
# count  23699.000000
# mean       2.070636
# std        1.078405
# min        0.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       19.000000

# %% [markdown]
# Присуствуют 0 значения, посмотрим совместно с 'total_area'

# %%
df.query('rooms==0')['total_area'].describe()
# Out:
# count    197.000000
# mean      29.081218
# std       25.864512
# min       15.000000
# 25%       24.000000
# 50%       26.000000
# 75%       28.000000
# max      371.000000
# Name: total_area, dtype: float64

# %% [markdown]
# ### Столбец 'ceiling_height'

# %%
investigate_column(['ceiling_height'])
# Out:
# Количества пропущенных значений: ceiling_height    9195
# dtype: int64
#
#        ceiling_height
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000

# %% [markdown]
# ### Столбец 'floors_total'

# %%
investigate_column(['floors_total'])
# Out:
# Количества пропущенных значений: floors_total    86
# dtype: int64
#
#        floors_total
# count  23613.000000
# mean      10.673824
# std        6.597173
# min        1.000000
# 25%        5.000000
# 50%        9.000000
# 75%       16.000000
# max       60.000000

# %% [markdown]
# ### Столбец 'living_area'

# %%
investigate_column(['living_area'])
# Out:
# Количества пропущенных значений: living_area    1903
# dtype: int64
#
#         living_area
# count  21796.000000
# mean      34.457852
# std       22.030445
# min        2.000000
# 25%       18.600000
# 50%       30.000000
# 75%       42.300000
# max      409.700000

# %% [markdown]
# ### Столбец 'floor'

# %%
investigate_column(['floor'])
# Out:
# Количества пропущенных значений: floor    0
# dtype: int64
#
#               floor
# count  23699.000000
# mean       5.892358
# std        4.885249
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        8.000000
# max       33.000000

# %% [markdown]
# ### Столбец 'kitchen_area'

# %%
investigate_column(['kitchen_area'])
# Out:
# Количества пропущенных значений: kitchen_area    2278
# dtype: int64
#
#        kitchen_area
# count  21421.000000
# mean      10.569807
# std        5.905438
# min        1.300000
# 25%        7.000000
# 50%        9.100000
# 75%       12.000000
# max      112.000000

# %% [markdown]
# ### Столбец 'airports_nearest'

# %%
investigate_column(['airports_nearest'])
# Out:
# Количества пропущенных значений: airports_nearest    5542
# dtype: int64
#
#        airports_nearest
# count      18157.000000
# mean       28793.672193
# std        12630.880622
# min            0.000000
# 25%        18585.000000
# 50%        26726.000000
# 75%        37273.000000
# max        84869.000000

# %% [markdown]
# ### Столбец 'cityCenters_nearest'

# %%
investigate_column(['cityCenters_nearest'])
# Out:
# Количества пропущенных значений: cityCenters_nearest    5519
# dtype: int64
#
#        cityCenters_nearest
# count         18180.000000
# mean          14191.277833
# std            8608.386210
# min             181.000000
# 25%            9238.000000
# 50%           13098.500000
# 75%           16293.000000
# max           65968.000000

# %% [markdown]
# ### Столбец 'parks_around3000'

# %%
investigate_column(['parks_around3000'])
# Out:
# Количества пропущенных значений: parks_around3000    5518
# dtype: int64
#
#        parks_around3000
# count      18181.000000
# mean           0.611408
# std            0.802074
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max            3.000000

# %% [markdown]
# ### Столбец 'parks_nearest'

# %%
investigate_column(['parks_nearest'])
# Out:
# Количества пропущенных значений: parks_nearest    15620
# dtype: int64
#
#        parks_nearest
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000

# %% [markdown]
# ### Столбец 'ponds_around3000'

# %%
investigate_column(['ponds_around3000'])
# Out:
# Количества пропущенных значений: ponds_around3000    5518
# dtype: int64
#
#        ponds_around3000
# count      18181.000000
# mean           0.770255
# std            0.938346
# min            0.000000
# 25%            0.000000
# 50%            1.000000
# 75%            1.000000
# max            3.000000

# %% [markdown]
# ### Столбец 'ponds_nearest'

# %%
investigate_column(['ponds_nearest'])
# Out:
# Количества пропущенных значений: ponds_nearest    14589
# dtype: int64
#
#        ponds_nearest
# count    9110.000000
# mean      517.980900
# std       277.720643
# min        13.000000
# 25%       294.000000
# 50%       502.000000
# 75%       729.000000
# max      1344.000000

# %% [markdown]
# ### Столбец 'days_exposition'

# %%
investigate_column(['days_exposition'])
# Out:
# Количества пропущенных значений: days_exposition    3181
# dtype: int64
#
#        days_exposition
# count     20518.000000
# mean        180.888634
# std         219.727988
# min           1.000000
# 25%          45.000000
# 50%          95.000000
# 75%         232.000000
# max        1580.000000

# %% [markdown]
# ### Столбец 'locality_name'

# %%
print('Количества пропущенных значений в "locality_name":', df['locality_name'].isna().sum())
print('Количество уникальных значений:', len(df['locality_name'].value_counts()))
print(df['locality_name'].value_counts())
display(df['locality_name'].sort_values().unique())
# Out:
# Количества пропущенных значений в "locality_name": 49
# Количество уникальных значений: 364
# Санкт-Петербург                    15721
# посёлок Мурино                       522
# посёлок Шушары                       440
# Всеволожск                           398
# Пушкин                               369
#                                    ...
# поселок Каложицы                       1
# посёлок Платформа 69-й километр        1
# поселок Почап                          1
# поселок Гончарово                      1
# посёлок Дзержинского                   1
# Name: locality_name, Length: 364, dtype: int64
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
# ...

# %%
# Заменим "ё" на "е" и "городской посeлок" на "посeлок городского типа":

df['locality_name'] = df['locality_name'].str.replace("ё", "e")
df['locality_name'] = df['locality_name'].str.replace("городской посeлок", "посeлок городского типа")
print('Количество уникальных значений:', len(df['locality_name'].value_counts()))
display(df['locality_name'].sort_values().unique())
# Out:
# Количество уникальных значений: 361
# array(['Бокситогорск', 'Волосово', 'Волхов', 'Всеволожск', 'Выборг',
#        'Высоцк', 'Гатчина', 'Зеленогорск', 'Ивангород', 'Каменногорск',
#        'Кингисепп', 'Кириши', 'Кировск', 'Колпино', 'Коммунар',
#        'Красное Село', 'Кронштадт', 'Кудрово', 'Лодейное Поле',
#        'Ломоносов', 'Луга', 'Любань', 'Мурино', 'Никольское',
#        'Новая Ладога', 'Отрадное', 'Павловск', 'Петергоф', 'Пикалeво',
#        'Подпорожье', 'Приморск', 'Приозерск', 'Пушкин', 'Санкт-Петербург',
#        'Светогорск', 'Сертолово', 'Сестрорецк', 'Сланцы', 'Сосновый Бор',
#        'Сясьстрой', 'Тихвин', 'Тосно', 'Шлиссельбург',
#        'городской поселок Большая Ижора', 'городской поселок Янино-1',
#        'деревня Агалатово', 'деревня Аро', 'деревня Батово',
#        'деревня Бегуницы', 'деревня Белогорка', 'деревня Большая Вруда',
#        'деревня Большая Пустомержа', 'деревня Большие Колпаны',
# ...

# %% [markdown]
# ### Выводы после первочной предобработки

# %% [markdown]
# **last_price**:
#
#      - Обнаруженные аномалии: Есть как сильно большие (763млн) так очень маленькие значения (12190р).
#      - Причины, по которым они могли возникнуть: не верная проставка цены- пропущенные цифры
#      - Как исправлять: С помощью графиков откинем явные аномалии
#      - Финальный тип и почему: Integer - для ислед хватит целочисленных значений, а также простота в операциях.
#
# **ceiling_height**:
#
#      - Обнаруженные аномалии: Наличие двухзначных значений, а также значей меньше 1.9м.
#      - Причины, по которым они могли возникнуть: простановка в разных ед.измерения(см/м), а также не простановка запятой в    двухзначных значениях
#      - Как исправлять: двухзначные значения /10 , конечные значения *100 для перевода в см
#      - Финальный тип и почему: Integer - т.к. домножили на 100 и перевели в целочисленные значения.
#
# **locality_name**:
#
#      - "ё" на "е"    и    "городской посeлок" на "посeлок городского типа"
#      - Пропущенных значений очень мало - 0,2%
#      - Удалим строки содержащие пустые значения в столбце
#
# **floors_total**:
#
#      - Пропущенные значения заполним совместно со стобцом 'floor' (нет пустых значений)
#
# **balcony**:
#
#      - Пропущенные значения заполним -0-, если человек не указал, скорей всего их нет.
#
# **rooms**:
#
#      - Присуствуют 0 значения в столбце, удалим строку с мах значением 371кв.м.

# %% [markdown]
# ### Исправим аномалии

# %% [markdown]
# #### last_price

# %%
investigate_column(['last_price'])
# Out:
# Количества пропущенных значений: last_price    0
# dtype: int64
#
#          last_price
# count  2.369900e+04
# mean   6.541549e+06
# std    1.088701e+07
# min    1.219000e+04
# 25%    3.400000e+06
# 50%    4.650000e+06
# 75%    6.800000e+06
# max    7.630000e+08

# %%
# посмотрим на гистограмму

df['last_price'].hist(figsize=(15,3), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Разобьем на 3 диапазона:
# - 0-600001;
# - 600000-60000001;
# - 60000000-800000000;

# %%
df.hist('last_price', bins=100, figsize=(15,3), range=(0, 600001));
df.hist('last_price', bins=100, figsize=(15,3), range=(600000, 60000001));
df.hist('last_price', bins=100, figsize=(15,3), range=(60000000, 800000000));

# %% [markdown]
# Уберем **400 000< аномалии <100 000 000**

# %%
print('Количества строк в df до удаления:', len(df))

df = df.loc[(df['last_price']>400000) & (df['last_price']<100000000)]
df.reset_index(inplace=True, drop=True)

print('Количества строк в df после удаления:', len(df))
# Out:
# Количества строк в df до удаления: 23699
# Количества строк в df после удаления: 23661

# %% [markdown]
# #### ceiling_height

# %%
investigate_column(['ceiling_height'])
# Out:
# Количества пропущенных значений: ceiling_height    9183
# dtype: int64
#
#        ceiling_height
# count    14478.000000
# mean         2.769863
# std          1.261192
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000

# %%
df['ceiling_height'].hist(figsize=(15,3), bins=100, range=(4,40))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Будем отталкиваться от того, что обычная высота потолков от 1.9 до 3.5м.
#
# Значения больше 19 и меньше 35 поделим на 10. Остальные удалим

# %%
index_list = df.query('ceiling_height > 19 and ceiling_height < 35').index 
df.loc[index_list, 'ceiling_height'] = df.loc[index_list, 'ceiling_height'] / 10
print(len(df.query('ceiling_height > 19 and ceiling_height < 35')))
# Out:
# 0

# %%
print('Количество строк перед удалением:', len(df))
index_list = df.query('ceiling_height>35 or ceiling_height<1.9 or 7<ceiling_height<19').index
df.drop(index_list, inplace=True, axis=0)
print('Количество строк после удалением:', len(df))
df.reset_index(inplace=True, drop=True)
# Out:
# Количество строк перед удалением: 23661
# Количество строк после удалением: 23651

# %% [markdown]
# Переведем значения в см, а затем заполним пропуски медианным значением

# %%
df['ceiling_height'] = df['ceiling_height'] * 100
df['ceiling_height'].median()
# Out:
# 265.0

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())
df['ceiling_height'] = df['ceiling_height'].astype(int)
print("Кол-во пропусков =", df['ceiling_height'].isna().sum())
# Out:
# Кол-во пропусков = 0

# %% [markdown]
# #### rooms

# %%
df.query('rooms==0')['total_area'].describe()
# Out:
# count    197.000000
# mean      29.081218
# std       25.864512
# min       15.000000
# 25%       24.000000
# 50%       26.000000
# 75%       28.000000
# max      371.000000
# Name: total_area, dtype: float64

# %%
print('Количество строк содержащих rooms==0 до удаления:', len(df.query('rooms==0')['total_area']))
df.drop(df.loc[(df['rooms']==0) & (df['total_area']==371)].index,inplace=True, axis=0)
print('Количество строк содержащих rooms==0 после удаления:', len(df.query('rooms==0')['total_area']))
df.query('rooms==0')['total_area'].describe()
# Out:
# Количество строк содержащих rooms==0 до удаления: 197
# Количество строк содержащих rooms==0 после удаления: 196
# count    196.000000
# mean      27.336735
# std        8.355491
# min       15.000000
# 25%       24.000000
# 50%       26.000000
# 75%       28.000000
# max       98.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Проверим сколько квартир с 0 комнатами-студии:

# %%
print('Количество квартир студий :', len(df.loc[(df['rooms']==0) & (df['studio']==True)]))
print()
print('Количество квартир не студий :', len(df.loc[(df['rooms']==0) & (df['studio']==False)]))
# Out:
# Количество квартир студий : 138
#
# Количество квартир не студий : 58

# %% [markdown]
# Посмотрим описание данных квартир не студий:

# %%
df.loc[(df['rooms']==0) & (df['studio']==False)]['total_area'].describe()
# Out:
# count    58.000000
# mean     26.706897
# std       4.069608
# min      16.000000
# 25%      25.000000
# 50%      26.000000
# 75%      28.000000
# max      42.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Заменим:
#
# 'rooms'-не студии, на 1.
#
# 'rooms'-студии оставим без изменений

# %%
df.loc[df.query('rooms==0 and studio==False').index, 'rooms'] = 1
print('Количество квартир студий :', len(df.loc[(df['rooms']==0) & (df['studio']==True)]))
print()
print('Количество квартир не студий :', len(df.loc[(df['rooms']==0) & (df['studio']==False)]))
# Out:
# Количество квартир студий : 138
#
# Количество квартир не студий : 0

# %% [markdown]
# Заменим значения с 0 значением на число комнат = 1

# %%
print(df['rooms'].value_counts())
# Out:
# 1     8100
# 2     7934
# 3     5809
# 4     1171
# 5      316
# 0      138
# 6      100
# 7       54
# 8       10
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 19       1
# 16       1
# Name: rooms, dtype: int64

# %% [markdown]
# ### Удалим строки

# %% [markdown]
# Удалим пустые строки в **locality_name**:

# %%
print('Количества пропущенных значений в "locality_name" до удаления:', df['locality_name'].isna().sum())

df['locality_name'].replace('', np.nan, inplace=True)
df.dropna(subset=['locality_name'], inplace=True)

print('Количества пропущенных значений в "locality_name" после удаления:', df['locality_name'].isna().sum())
# Out:
# Количества пропущенных значений в "locality_name" до удаления: 49
# Количества пропущенных значений в "locality_name" после удаления: 0

# %% [markdown]
# ### Заполним пропуски

# %% [markdown]
# #### balcony

# %%
df['balcony'].isna().sum()
# Out:
# 11488

# %%
df['balcony'] = df['balcony'].fillna(0)

# %%
df['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### floors_total

# %% [markdown]
# Заполним пустые значения:
#
# - если значение floor 1-5 то это 5-ти этажка (так как 5 и 9 этажки самые распространенные)
# - если значение floor 6-9 то это 9-ти этажка (так как 5 и 9 этажки самые распространенные)
# - все что выше будем - приравняем floors_total к (floor-1) (так как если приравнять к первому или последнему это может повлиять на последующий анализ, пусть это будет не тот и не другой)

# %%
df.loc[df['floors_total'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 186              12    11640000          65  2018-10-02T00:00:00      2
# 237               4     2438033          28  2016-11-23T00:00:00      1
# 457               4     9788348          70  2015-08-01T00:00:00      2
# 671               4     6051191          93  2017-04-06T00:00:00      3
# 1752              5     3600000          39  2017-04-22T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 22497             5     8500000          63  2017-05-24T00:00:00      2
# 22610             4     4574160          64  2017-04-02T00:00:00      2
# 22762             0    14569263         110  2016-11-20T00:00:00      3
# 23542             0    21187872         123  2017-04-25T00:00:00      3
# 23610             6     3063600          43  2016-11-28T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
df.loc[(df['floors_total'].isna()) & (1<=df['floor']) & (df['floor']<=5), 'floors_total'] = 5
df.loc[(df['floors_total'].isna()) & (6<=df['floor']) & (df['floor']<=9), 'floors_total'] = 9
df.loc[(df['floors_total'].isna()) & (df['floor']>9), 'floors_total'] = df['floor']-1
print('Количества пропущенных значений в "floors_total" :', df['floors_total'].isna().sum())
# Out:
# Количества пропущенных значений в "floors_total" : 0

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### •	Цена квадратного метра

# %%
df['sq_metr_pr'] = round(df['last_price'] / df['total_area'])
df['sq_metr_pr'] = df['sq_metr_pr'].astype(int)
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20    13000000         108  2019-03-07T00:00:00      3
# 1             7     3350000          40  2018-12-04T00:00:00      1
# 2            10     5196000          56  2015-08-20T00:00:00      2
# 3             0    64900000         159  2015-07-24T00:00:00      3
# 4             2    10000000         100  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0             270          16.0         51.0      8          NaN  ...
# 1             265          11.0         18.6      1          NaN  ...
# 2             265           5.0         34.3      4          NaN  ...
# 3             265          14.0          NaN      9          NaN  ...
# 4             303          14.0         32.0     13          NaN  ...
#
#    balcony    locality_name  airports_nearest  cityCenters_nearest  \
# ...

# %% [markdown]
# ### •	День недели, месяц и год публикации объявления

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%d %H:%M')
df['year_exp'] = df['first_day_exposition'].dt.year
df['month_exp'] = df['first_day_exposition'].dt.month
df['day_exp'] = df['first_day_exposition'].dt.weekday
display(df.loc[:,['first_day_exposition', 'year_exp', 'month_exp', 'day_exp']].head())
# Out:
#   first_day_exposition  year_exp  month_exp  day_exp
# 0           2019-03-07      2019          3        3
# 1           2018-12-04      2018         12        1
# 2           2015-08-20      2015          8        3
# 3           2015-07-24      2015          7        4
# 4           2018-06-19      2018          6        1

# %% [markdown]
# ### •	Этаж квартиры; варианты — первый, последний, другой

# %%
df['at_floor'] = np.nan

def floor_insert(row):
    if row['floor']==1:
        return 'первый'
    elif row['floor']==row['floors_total']:
        return 'последний'
    else:
        return 'другой'

df['at_floor'] = df.apply(floor_insert, axis=1)

print(df['at_floor'].value_counts(dropna=False))
# Out:
# другой       17369
# последний     3323
# первый        2909
# Name: at_floor, dtype: int64

# %%
display(df.loc[:,['floor', 'floors_total', 'at_floor']].head(10))
# Out:
#    floor  floors_total at_floor
# 0      8          16.0   другой
# 1      1          11.0   первый
# 2      4           5.0   другой
# 3      9          14.0   другой
# 4     13          14.0   другой
# 5      5          12.0   другой
# 6      6          26.0   другой
# 7     22          24.0   другой
# 8     26          27.0   другой
# 9      7           9.0   другой

# %% [markdown]
# ### •	Соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
df['liv_tot'] = round(df['living_area'] / df['total_area'],2)
df['kit_tot'] = round(df['kitchen_area'] / df['total_area'],2)
display(df[['liv_tot', 'kit_tot']])
# Out:
#        liv_tot  kit_tot
# 0         0.47     0.23
# 1         0.46     0.28
# 2         0.61     0.15
# 3          NaN      NaN
# 4         0.32     0.41
# ...        ...      ...
# 23646     0.55     0.10
# 23647     0.64     0.14
# 23648     0.53      NaN
# 23649      NaN     0.31
# 23650     0.38     0.28
#
# [23601 rows x 2 columns]

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра

# %% [markdown]
# Построим гистограммы для каждого параметра:

# %%
df['total_area'].hist(figsize=(12,3), bins=60),
# Out:
# (<AxesSubplot:>,)

# %%
df['total_area'].hist(range=(0,100),figsize=(14,3), bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Вывод**
#
# - Больше всего квартир с площадями 30-50 кв.м - это 1 и 2-х комнатные. С увеличением площади уменьшается и кол-во

# %%
df['last_price'].hist(figsize=(12,3), bins=60)
# Out:
# <AxesSubplot:>

# %%
df['last_price'].hist(range=(0,10000000),figsize=(12,3), bins=60)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Вывод**
#
# - Больше всего квартир продаются по цене в диапазоне 1,8-7,5 млн.руб. Пик же продажи квартир идет в по цене около 3,8 мнн

# %%
df['rooms'].hist(figsize=(12,3), bins=60)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Вывод**
#
# - Больше всего квартир 1 и 2 комн.квартир, немного больше 8000 и около 8000 соответсвенно.
# - 3 комнат. кварт немного не достают до 6000, далее кол-во сильно сокращается

# %%
df['ceiling_height'].hist(figsize=(12,3), bins=60)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Вывод**
#
# - Основная часть квартир имеют квартиры с высотой потолков 250-300см

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
print(df['days_exposition'].describe())
df.boxplot(column='days_exposition', figsize=(3,7))
plt.show()
df['days_exposition'].hist(figsize=(12,3), bins=60)
# Out:
# count    20426.000000
# mean       180.514296
# std        219.634659
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64
# <AxesSubplot:>

# %%
df.hist('days_exposition', bins=100, figsize=(15,3), range=(0, 101));
df.hist('days_exposition', bins=100, figsize=(15,3), range=(100, 401));
df.hist('days_exposition', bins=100, figsize=(15,3), range=(400, 1600));

# %%
print('Медиана =', df['days_exposition'].median())
print('Средняя =', df['days_exposition'].mean())
# Out:
# Медиана = 95.0
# Средняя = 180.514295505728

# %% [markdown]
# **Вывод**
#
# Из приведенных значений (из верхних гистограмм) можно сделать вывод, что продажа квартиры занимает от 3 до 6 месяцев. Все что продается раньше 40 дней можно назвать быстрой продажей (находится до первого пика средней гистограммы). Необычайно долгие продажи начинаются от 2 лет (нижняя гистограмма)

# %% [markdown]
# ###  Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %% [markdown]
# - **last_price** - Есть как сильно больщие >100млн.руб (**max=763млн**) так и очень маленькие значения (**12190р**). Избавились от них .
#
# - **rooms** - присутствовали значения 0 комнат.
#
# - **ceiling_height** - были обнаружены слишком маленькие значения ниже 180см, а также слишком высоки выше 10м, - их удалили. И еще были замечены значения 20-33, при анализе строк было выявлено , что это обычные квартиры с высотой 2-3,3 метра, - исправили
#
# - **locality_name** - были обнаружены значения где "поселок" написан с буквой "ё" - исправлено. Еще присутствовали значения: "городской поселок" и "поселок городского типа" , что является одним и тем же; иправили на "поселок городского типа".

# %% [markdown]
# ###  Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# #### Зависимость Цены от Площади

# %%
def corr1(column):
    print('Корелляция цены от',column , df['last_price'].corr(df[column]))
    df.plot(x=column, y='last_price', kind='scatter', grid=True, figsize=(14,7), alpha=0.5);

corr1('total_area')
# Out:
# Корелляция цены от total_area 0.7684016692111053

# %% [markdown]
# **Вывод**:
#
# - При возрастании площади, возрастает цена

# %% [markdown]
# #### Зависимость Цены от Кол-ва комнат

# %%
corr1('rooms')
# Out:
# Корелляция цены от rooms 0.474894005728165

# %% [markdown]
# **Вывод**:
#
# - Зависимость цены от кол-ва комнат слабо прослеживается. Она увеличивается, при возрастании комнат от 1 до 3

# %% [markdown]
# #### Зависимость Цены от Удалённости от центра

# %%
corr1('cityCenters_nearest')
# Out:
# Корелляция цены от cityCenters_nearest -0.30078878742787324

# %% [markdown]
# **Вывод**:
#
# - Цена не так уж сильно зависит от расстояния до центра, причем количество более дорогих квартир возрастает при увеличении расстояния до 5-6км, а потом снижается.
# - Надо отметить всплеск цен (до 5-7млн) и продаж на растоянии 45-55км, возможно там какой-то крупный населенный пункт(регион/область)

# %% [markdown]
# #### Зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом

# %%
cat_fl_mean = df.groupby('at_floor')['last_price'].mean();
cat_fl_mean.plot(x=cat_fl_mean.index, y=cat_fl_mean.values, kind='bar', grid=True, figsize=(6,5));

# %% [markdown]
# **Вывод**
#
# - Первый этаж любят меньше всего

# %% [markdown]
# #### Зависимость от даты размещения: дня недели, месяца и года

# %%
day_fl_mean = df.groupby('day_exp')['last_price'].mean();
day_fl_mean.plot(x=day_fl_mean.index, y=day_fl_mean.values, kind='bar', grid=True, figsize=(6,5));

# %%
month_fl_mean = df.groupby('month_exp')['last_price'].mean();
month_fl_mean.plot(x=month_fl_mean.index, y=month_fl_mean.values, kind='bar', grid=True, figsize=(6,5));

# %%
year_fl_mean = df.groupby('year_exp')['last_price'].mean();
year_fl_mean.plot(x=year_fl_mean.index, y=year_fl_mean.values, kind='bar', grid=True, figsize=(6,5));

# %%
df.plot(x='day_exp', y='last_price', kind='hexbin', gridsize=50, sharex=False, grid=True, figsize=(16,4),ylim=(0,15000000))
# Out:
# <AxesSubplot:xlabel='day_exp', ylabel='last_price'>

# %%
df.plot(x='month_exp', y='last_price', kind='hexbin', gridsize=50, sharex=False, grid=True, figsize=(16,4),ylim=(0,15000000))
# Out:
# <AxesSubplot:xlabel='month_exp', ylabel='last_price'>

# %%
df.plot(x='year_exp', y='last_price', kind='hexbin', gridsize=50, sharex=False, grid=True, figsize=(16,4),ylim=(0,15000000));

# %% [markdown]
# #### Вывод

# %% [markdown]
# - Больше всего на стоимость квартиры влияет её площадь(прямопропорцианальная зависимость). Среднее влияние оказывает удаленность от центра(обратнопропорцианальная зависимость) и количество комнат (особенно хорошо видна прямопропорцианальная зависимость на отрезке 1-3 комнаты, все что выше уже не коррелирует).
#
# - Также надо отметить, что есть зависимость от этажа - первый этаж мало кто любит и цена его существенно отличается от остальных; люди предпочитают не первый и не последний этаж - его цена выше(но на немного выше последнего).
#
# - Дата же размещения не оказывает влияния на цену.

# %% [markdown]
# ###  Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце locality_name.

# %%
loc10 = df.groupby('locality_name')['sq_metr_pr'].agg(['count', 'mean']).sort_values(by='count', ascending=False).head(10)
loc10.columns = ['flats', 'sq_metr_price']
loc10.reset_index(inplace=True)
print(loc10)
# Out:
#        locality_name  flats  sq_metr_price
# 0    Санкт-Петербург  15675  114069.887145
# 1     посeлок Мурино    522   86379.980843
# 2     посeлок Шушары    440   79068.609091
# 3         Всеволожск    398   68985.233668
# 4             Пушкин    369  103611.368564
# 5            Колпино    338   75735.612426
# 6  посeлок Парголово    327   90675.590214
# 7            Гатчина    307   69045.524430
# 8    деревня Кудрово    299   93002.193980
# 9             Выборг    237   58296.143460

# %% [markdown]
# **Найдем:**
# - Населённый пункт, где cамая низкая стоимость жилья
# - Населённый пункт, где cамая высокая стоимость жилья

# %%
print(loc10.loc[loc10['sq_metr_price']==loc10['sq_metr_price'].min()])
print(loc10.loc[loc10['sq_metr_price']==loc10['sq_metr_price'].max()])
# Out:
#   locality_name  flats  sq_metr_price
# 9        Выборг    237    58296.14346
#      locality_name  flats  sq_metr_price
# 0  Санкт-Петербург  15675  114069.887145

# %% [markdown]
# ###  Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.

# %%
spb = df.loc[df['locality_name']=='Санкт-Петербург',['last_price', 'cityCenters_nearest']].reset_index(drop=True) # Вариант №2
spb['dist_center_km'] = round(spb['cityCenters_nearest']/1000)
print(spb.head(10))
# Out:
#    last_price  cityCenters_nearest  dist_center_km
# 0    13000000              16028.0            16.0
# 1     5196000              13933.0            14.0
# 2    64900000               6800.0             7.0
# 3    10000000               8098.0             8.0
# 4     7915000              11634.0            12.0
# 5     5400000              15008.0            15.0
# 6     5050000              13878.0            14.0
# 7     4650000              14259.0            14.0
# 8     6700000              10698.0            11.0
# 9     4180000              14616.0            15.0

# %%
price_km_spb = spb.pivot_table(index='dist_center_km', values='last_price', aggfunc='mean')
price_km_spb.head(8)
# Out:
#                   last_price
# dist_center_km
# 0.0             2.654331e+07
# 1.0             1.629391e+07
# 2.0             1.501556e+07
# 3.0             1.112658e+07
# 4.0             1.142364e+07
# 5.0             1.282362e+07
# 6.0             1.370633e+07
# 7.0             1.396663e+07

# %%
price_km_spb.plot(kind='bar', grid=True, figsize=(14,8))
# Out:
# <AxesSubplot:xlabel='dist_center_km'>

# %% [markdown]
# **Вывод**
#
# По гистограмме видно, что на расстоянии ДО 1 (это 0 км) км от центра цена очень высока (около 26,5 млн.р за квартиру) и сильно меняется уже после 1 км. от центра (16,3 млн.р за квартиру), все, что в радиусе до 1 км от центра - это и есть "самый центр". Есть еще одна граница, она находится в районе 8 км от самого центра, после которой следует сильное падение цены (с 14млн до 9млн) и после начинает убывать постепенно. Это и есть центральная зона (в радиусе 8 км отцентра). Будем называть обе территории вместе - Центр.

# %% [markdown]
# ###  Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %%
print('Питер - ЦЕНТР')
spb_center = df.query('cityCenters_nearest < 8000 ') 
display(spb_center.sample(3))
print()
print('Питер - ВЕСЬ')
spb_all = df.query(' locality_name == "Санкт-Петербург" ') 
display(spb_all.head(3))
# Out:
# Питер - ЦЕНТР
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 4789             12     7000000          52           2016-04-26      2
# 14695             8    22523032         146           2018-07-06      3
# 14552             7     9500000          98           2016-05-27      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 4789              265           5.0         37.0      5          NaN  ...
# 14695             265          12.0          NaN      5          NaN  ...
# 14552             310           7.0         49.6      7          NaN  ...
#
#        ponds_around3000  ponds_nearest  days_exposition  sq_metr_pr year_exp  \
# 4789                2.0          422.0            301.0      134615     2016
# 14695               1.0          936.0              NaN      154267     2018
# 14552               1.0          217.0            912.0       96939     2016
#
# ...

# %% [markdown]
# #### Изучение следующих параметров: площадь, цена, число комнат, высота потолков.

# %%
for col in ['total_area', 'last_price', 'rooms', 'ceiling_height']:
    spb_center.plot(y=col, kind='hist', grid=True, figsize=(14,3), bins=75, alpha=0.8, legend=True, label='ЦЕНТР - '+col);
    spb_all.plot(y=col, kind='hist', grid=True, figsize=(14,3), bins=75, alpha=0.5, legend=True, label='ПИТЕР - '+col);
    plt.show()

# %% [markdown]
# **Вывод:** В ходе анализа гистограмм были выявлены следущие особенности:
#
# - Доля проданных квартир с большой площадью в Центре значительно выше, нежели по всему Городу
# - Конечно же цена на квартиры выше в Центре, чем в Городе
# - Большая доля продаж в Центре приходится на 2-х и 3-х комнатные квартиры, а по Городу на 1-а и 2-х комнатные
# - Также можно видеть, что в Центре доля проданых квартир с высокими потолками - 3м высока, а в Городе высока доля с высотой 2,5м. Но подавляющее большинство и там и там идет по высоте 2,65м (так как мы её медианой сделали, здесь может быть некоторое искажение данных из-за этого)

# %% [markdown]
# #### Выделяем факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления) и сравниваем Питер и Центр

# %%
print('Выделяем факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления)')
print()
def corr_spb(column):   
    plt.show()
    print('Корелляция цены в ЦЕНТР от',column , spb_center['last_price'].corr(spb_center[column]))
    spb_center.plot(x=column, y='last_price', kind='scatter', grid=True, figsize=(14,4));
    plt.show()
    print('Корелляция цены в ПИТЕР от',column , spb_all['last_price'].corr(spb_all[column]))
    spb_all.plot(x=column, y='last_price', kind='scatter', grid=True, figsize=(14,4));

for сol in ['rooms', 'floor', 'cityCenters_nearest']:
    corr_spb(сol)


plt.show()



cat_fl_mean_spb_center = spb_center.groupby('at_floor')['last_price'].mean();
cat_fl_mean_spb_all = spb_all.groupby('at_floor')['last_price'].mean();
print('ЦЕНТР')
plt.show()
cat_fl_mean_spb_center.plot(x=cat_fl_mean.index, y=cat_fl_mean.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
plt.show()
print('ПИТЕР')
cat_fl_mean_spb_all.plot(x=cat_fl_mean.index, y=cat_fl_mean.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
# Out:
# Выделяем факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления)
#
# Корелляция цены в ЦЕНТР от rooms 0.415245461044395
# Корелляция цены в ПИТЕР от rooms 0.4906571437006842
# Корелляция цены в ЦЕНТР от floor 0.13161760842554476
# Корелляция цены в ПИТЕР от floor -0.008605074177973326
# Корелляция цены в ЦЕНТР от cityCenters_nearest -0.06000126866823183
# Корелляция цены в ПИТЕР от cityCenters_nearest -0.3724672658920975
# ЦЕНТР
# ПИТЕР

# %%
print('---------День---------')
day_fl_mean_spb_center = spb_center.groupby('day_exp')['last_price'].mean();
day_fl_mean_spb_all = spb_all.groupby('day_exp')['last_price'].mean();
print('ЦЕНТР')
plt.show()
day_fl_mean_spb_center.plot(x=day_fl_mean.index, y=day_fl_mean.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
plt.show()
print('ПИТЕР')
day_fl_mean_spb_all.plot(x=day_fl_mean.index, y=day_fl_mean.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
plt.show()
print()
print('---------Месяц---------')
print()
month_fl_mean_spb_center = spb_center.groupby('month_exp')['last_price'].mean();
month_fl_mean_spb_all = spb_all.groupby('month_exp')['last_price'].mean();
print('ЦЕНТР')
plt.show()
month_fl_mean_spb_center.plot(x=month_fl_mean.index, y=month_fl_mean.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
plt.show()
print('ПИТЕР')
month_fl_mean_spb_all.plot(x=month_fl_mean.index, y=month_fl_mean.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
plt.show()
print()
print('---------Год---------')
print()
year_fl_mean_spb_center = spb_center.groupby('year_exp')['last_price'].mean();
year_fl_mean_spb_all = spb_all.groupby('year_exp')['last_price'].mean();
print('ЦЕНТР')
plt.show()
year_fl_mean_spb_center.plot(x=year_fl_mean.index, y=year_fl_mean.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
plt.show()
print('ПИТЕР')
year_fl_mean_spb_all.plot(x=year_fl_mean.index, y=year_fl_mean.values, kind='bar', grid=True, figsize=(5,4), alpha=0.5);
plt.show()
# Out:
# ---------День---------
# ЦЕНТР
# ПИТЕР
# ---------Месяц---------
#
# ЦЕНТР
# ПИТЕР
# ---------Год---------
#
# ЦЕНТР
# ПИТЕР

# %% [markdown]
# **Вывод:** В ходе анализа были выявленны следующие особенности:
#
# - Количество комнат чуть слабее влияет на цену в Центре города
# - Если в Городе есть слабая зависимость от расстояния от центра, то в Центре такой зависимости нет
# - По остальным параметрам зависимости не прослеживаются
#
# - Есть еще особенность - что в Центре, что и в самом Городе продается больше квартир на последних этажах, по сравнению со всеми квартирами в df

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Для анализа был дан ДатаСет с информацией по продаже квартир. Состоял из 22 колонок и 23699 строк. 7 колонок не пригодились (total_images, open_plan, balcony, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest).
#
# В столбце ceiling_height пропуски заменены медианами
#
# Столбец first_day_exposition приведен к типу datetime64
#
# В числовых столбцах заменены типы на int, кроме столбцов с площадями(округлено до 0,1), и столбцов с расстояниями (оставили float - здесь мрого пропусков)
#
# Обрезаны сильные выбросы в столбцах где они имели место.
#
# **По заданию было добавлено 7 столбцов, в которых были подсчитаны дополнительные параметры:**
#
# -цена квадратного метра;
# -день недели, месяц и год публикации объявления;
# -этаж квартиры; варианты — первый, последний, другой;
# -соотношение жилой и общей площади, а также отношение площади кухни к общей.
# Был проведен анализ и сделаны выводы по заданым вопросам:
#
# Больше всего квартир с площадями 30-46 кв.м - это, похоже, самые популярные 1 и 2-х комнатные. Далее идут скорее всего 2 и 3 комнатные с площадью до 75 кв.м.
# Сделан вывод, что больше всего квартир продаются по цене в диапазоне 1,8-7,5 млн.руб. Пик же продажи квартир идет в по цене около 3,8 мнн.
# самые популярные квартиры - 1комнатная(чуть больше 8000) и 2комнатные(около 8000). 3комнатных тоже довольно много - чуть меньше 6000, ну а дальше кол-во сильно сокращаетя.
# Больше всего квартир с высотой потолков 250 - 300 см, подавляющее большинство почти половина с высотой 265 см.
#
# **Факторы больше всего влияющие на стоимость квартиры**:
#
# -Больше всего на стоимость квартиры влияет её площадь(прямопропорцианальная зависимость).
# -Среднее влияние оказывает удаленность от центра(обратнопропорцианальная зависимость) и количество комнат (особенно хорошо видна прямопропорцианальная зависимость на отрезке 1-3 комнаты, все что выше уже не коррелирует).
# -Также надо отметить, что есть зависимость от этажа - первый этаж мало кто любит и цена его существенно отличается от остальных; люди предпочитают не первый и не последний этаж - его цена выше(но на немного выше последнего).
#
# Подавляющее большинство квартир продается в Питере - 15675, а цена около 114069р/кв.м. Помимо Питера в Топ10 входят: поселок Мурино, поселок Шушары, Всеволожск, Пушкин, Колпино, поселок Парголово, Гатчина, деревня Кудрово, Выборг с ценами 58000 - 103600р/кв.м
#
# В ходе анализа квартир в центре Питера было выявлено - что на расстоянии ДО 1 (это 0 км) км от центра цена очень высока (около 26,5 млн.р за квартиру) и сильно меняется уже после 1 км. от центра (16,3 млн.р за квартиру), все, что в радиусе до 1 км от центра - это и есть "самый центр". Есть еще одна граница, она находится в районе 8 км от самого центра, после которой следует сильное падение цены (с 14млн до 9млн) и после начинает убывать постепенно. Это и есть центральная зона (в радиусе 8 км от центра). Будем называть обе территории вместе - Центр.
#
# Доля проданных квартир с большой площадью в Центре значительно выше, нежели по всему Городу. Конечно же цена на квартиры выше в Центре, чем в Городе. Большая доля продаж в Центре приходится на 2-х и 3-х комнатные квартиры, а по Городу на 1-а и 2-х комнатные. Также можно видеть, что в Центре доля проданых квартир с высокими потолками - 3м высока, а в Городе высока доля с высотой 2,5м. Но подавляющее большинство и там и там идет по высоте 2,65м
# Если в Городе есть слабая зависимость от расстояния от центра, то в Центре такой зависимости нет. Есть еще особенность - что в Центре, что и в самом Городе продается больше квартир на последних этажах, по сравнению со всеми квартирами в базе объявлений
