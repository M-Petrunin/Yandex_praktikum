# %% [markdown]
# Привет, я - Дмитрий Утенков. С удовольствием проверю твою нетленку 😉.
#
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их,** это может усложнить и затянуть повторную проверку.
#
# Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Если все сделано хорошо.</div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Некритичное замечание, реккомендация на будущее. Для принятия проекта исправление не обязательно.</div>
#
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Критичная ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Ах. О чем я думал! Куда смотрел...
# </div>
#
# Если писать особо нечего, просто оставляй комментарий с галочкой
#
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# ☑️
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Общее впечатление:</b>
#
# - Спасибо за работу :)
# - Хорошая работа. Отличный детальный разбор параметров!
# - Обязательно перед сдачей перезапускай весь ноутбук.;
# - Более бережно относись к данным;
# - Подтяни оформление и я смогу принять работу😉
#
# </div>

# %% [markdown]
# # Исследование надежности заемщиков.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Хорошая практика начинать проект с контекста, описания задачи, возможного хода\плана исследования, а также описания имеющихся данных. Очень надеюсь, что ты будешь уделять этому внимание и в последующих проектах</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Добавил описание
# </div>

# %% [markdown]
# Описание проекта
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
# Результаты исследования будут учтены при построении модели кредитного скоринга — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
#
# ### Описание данных
#     children — количество детей в семье
#     days_employed — общий трудовой стаж в днях
#     dob_years — возраст клиента в годах
#     education — уровень образования клиента
#     education_id — идентификатор уровня образования
#     family_status — семейное положение
#     family_status_id — идентификатор семейного положения
#     gender — пол клиента
#     income_type — тип занятости
#     debt — имел ли задолженность по возврату кредитов
#     total_income — ежемесячный доход
#     purpose — цель получения кредита

# %% [markdown]
# ### Шаг 1. Обзор данных

# %% [markdown]
# Выгрузим первые 10 строк таблицы

# %%
import pandas as pd
borrower_reliability = pd.read_csv('/datasets/data.csv')
borrower_reliability.head(10)
#borrower_reliability.info()
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0    -926.185831         27    высшее             0
# 6         0   -2879.202052         43    высшее             0
# 7         0    -152.779569         50   СРЕДНЕЕ             1
# 8         2   -6929.865299         35    ВЫСШЕЕ             0
# 9         0   -2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# 2   женат / замужем                 0      M   сотрудник     0  145885.952297
# 3   женат / замужем                 0      M   сотрудник     0  267628.550329
# 4  гражданский брак                 1      F   пенсионер     0  158616.077870
# 5  гражданский брак                 1      M   компаньон     0  255763.565419
# 6   женат / замужем                 0      F   компаньон     0  240525.971920
# 7   женат / замужем                 0      M   сотрудник     0  135823.934197
# 8  гражданский брак                 1      F   сотрудник     0   95856.832424
# 9   женат / замужем                 0      M   сотрудник     0  144425.938277
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу
# 5               покупка жилья
# 6           операции с жильем
# 7                 образование
# 8       на проведение свадьбы
# 9     покупка жилья для семьи

# %% [markdown]
# В глаза сразу бросаются отрицательные значения в столбце -***days_employed***, разная высота шрифта - ***education***,
# большое количество цифр - ***total_income***

# %% [markdown]
# ### Шаг 2.1 Заполнение пропусков

# %% [markdown]
# Проверим кол-ва пропусков, и в каких столбцах находится

# %%
borrower_reliability.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %% [markdown]
# **days_employed** и **total_income** 2174/21525= 10% не заполнены

# %% [markdown]
# Проверим сколько значений в столбце **'days_employed'** >0 и сколько <0:

# %%
print("Количество строк с 'days_employed' > 0:", borrower_reliability[borrower_reliability['days_employed'] > 0].shape[0])
print("Количество строк с 'days_employed' < 0:", borrower_reliability[borrower_reliability['days_employed'] < 0].shape[0])
# Out:
# Количество строк с 'days_employed' > 0: 3445
# Количество строк с 'days_employed' < 0: 15906

# %% [markdown]
# Сгрупируем данные с учетом того, что **трудовой стаж >0, а также что тип занятости - пенсионер**. Чтобы по этим значеним найди медианну и заполнить пустые столбцы.

# %%
data_pens = borrower_reliability[(borrower_reliability['days_employed'] > 0) & (borrower_reliability['income_type'] == 'пенсионер')]
print("Медиана отработанных дней среди пенсионеров:", data_pens['days_employed'].median())
# Out:
# Медиана отработанных дней среди пенсионеров: 365213.3062657312

# %% [markdown]
# Заполним медианным значением в столбцах **days_employed** пустые строки:

# %%
borrower_reliability['days_employed'] = borrower_reliability['days_employed'].fillna(data_pens['days_employed'].median())

# %% [markdown]
# Найдем медиану всех значенией **"total_income"**, сгруппированных по типу **"income_type"** и найдя медианные значения **"total_income"** для каждого типа.

# %%
med_total_income = borrower_reliability.groupby('income_type')['total_income'].median()


print(med_total_income)
# Out:
# income_type
# безработный        131339.751676
# в декрете           53829.130729
# госслужащий        150447.935283
# компаньон          172357.950966
# пенсионер          118514.486412
# предприниматель    499163.144947
# сотрудник          142594.396847
# студент             98201.625314
# Name: total_income, dtype: float64

# %% [markdown]
# Проверим количество пропусков по каждому типу 'income_type':

# %%
print('Кол-во пропусков в безработный:', borrower_reliability.query('income_type=="безработный" ')['total_income'].isna().sum())
print('Кол-во пропусков в в декрете:', borrower_reliability.query('income_type=="в декрете" ')['total_income'].isna().sum())
print('Кол-во пропусков в госслужащий:', borrower_reliability.query('income_type=="госслужащий" ')['total_income'].isna().sum())
print('Кол-во пропусков в компаньон:', borrower_reliability.query('income_type=="компаньон" ')['total_income'].isna().sum())
print('Кол-во пропусков в пенсионер:', borrower_reliability.query('income_type=="пенсионер" ')['total_income'].isna().sum())
print('Кол-во пропусков в предприниматель:', borrower_reliability.query('income_type=="предприниматель" ')['total_income'].isna().sum())
print('Кол-во пропусков в сотрудник:', borrower_reliability.query('income_type=="сотрудник" ')['total_income'].isna().sum())
print('Кол-во пропусков в студент:', borrower_reliability.query('income_type=="студент" ')['total_income'].isna().sum())
# Out:
# Кол-во пропусков в безработный: 0
# Кол-во пропусков в в декрете: 0
# Кол-во пропусков в госслужащий: 147
# Кол-во пропусков в компаньон: 508
# Кол-во пропусков в пенсионер: 413
# Кол-во пропусков в предприниматель: 1
# Кол-во пропусков в сотрудник: 1105
# Кол-во пропусков в студент: 0

# %% [markdown]
# Заменим пустые значения в **госслужащий-компаньон-пенсионер-предприниматель-сотрудник** соответствующими значениями из **med_total_income**:

# %%
borrower_reliability.loc[(borrower_reliability['total_income'].isnull())\
                          & (borrower_reliability['income_type'] == "госслужащий"),\
                          'total_income'] = med_total_income['госслужащий']
print('Кол-во пропусков в госслужащий:', borrower_reliability.query('income_type=="госслужащий" ')['total_income'].isna().sum())

borrower_reliability.loc[(borrower_reliability['total_income'].isnull())\
                          & (borrower_reliability['income_type'] == "компаньон"),\
                          'total_income'] = med_total_income['компаньон']
print('Кол-во пропусков в компаньон:', borrower_reliability.query('income_type=="компаньон" ')['total_income'].isna().sum())

borrower_reliability.loc[(borrower_reliability['total_income'].isnull())\
                          & (borrower_reliability['income_type'] == "пенсионер"),\
                          'total_income'] = med_total_income['пенсионер']
print('Кол-во пропусков в пенсионер:', borrower_reliability.query('income_type=="пенсионер" ')['total_income'].isna().sum())

borrower_reliability.loc[(borrower_reliability['total_income'].isnull())\
                          & (borrower_reliability['income_type'] == "предприниматель"),\
                          'total_income'] = med_total_income['предприниматель']
print('Кол-во пропусков в предприниматель:', borrower_reliability.query('income_type=="предприниматель" ')['total_income'].isna().sum())

borrower_reliability.loc[(borrower_reliability['total_income'].isnull())\
                          & (borrower_reliability['income_type'] == "сотрудник"),\
                          'total_income'] = med_total_income['сотрудник']
print('Кол-во пропусков в сотрудник:', borrower_reliability.query('income_type=="сотрудник" ')['total_income'].isna().sum())
# Out:
# Кол-во пропусков в госслужащий: 0
# Кол-во пропусков в компаньон: 0
# Кол-во пропусков в пенсионер: 0
# Кол-во пропусков в предприниматель: 0
# Кол-во пропусков в сотрудник: 0

# %%
borrower_reliability['total_income'].isna().sum()
# Out:
# 0

# %%
borrower_reliability.isna().sum()
# Out:
# children            0
# days_employed       0
# dob_years           0
# education           0
# education_id        0
# family_status       0
# family_status_id    0
# gender              0
# income_type         0
# debt                0
# total_income        0
# purpose             0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера v4❌:</b>
#
# Увы, к моменту запуска твоей строки, уже нет незаполненых строк. Найди ошибку, код бесполезен.
#
# Далее ты пытаешься заполняешь медианой безработного.
# Пожалуйста не заполняй напрямую числами. В реальной работе, всегда надо быть готовым к тому, что данные будут изменяться.
#
# И на последок, хотелось бы увидеть заполнение медианой: "По каждой категории *income_type*".
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
#
# 1. Мдааа.. не удалил предыдущий код! удалил чтобы не мешался.
#
# 2. Вроде как разобрался что от меня требовалось.. надеюсь верно
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера v5❌:</b>
#
# Максим соберись пожалуйста.
#
# Я прошу:
# "Оценить *total_income* логично группируя медианами по *income_type*. По каждой категории *income_type*."
#
# Это значит, что пропущеные значения *total_income* по пенсионерам надо заполнить медианой по пенсионерам, пропущеные по сотрудникам - медианой сотрудников и т.п.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента v5:</b>
#
# Прошу прощения...
#
# Пункт 2.1 переделал!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b>
# Так оформлять нельзя. Представь,  что ты делаешь презентацию на работе перед серьезными дядками которые не верят словам. Разбивай все мелкими блоками и показывай то, что комментируешь. Пожалуйста, воспользуйся методичкой по оформлению проектов, что бы исправить эти недостатки. Для получения ссылки на методичку и доступа к ней обратись к своему куратору.
#
# Пропущеных значений очень много, поэтому надо постараться не исказить данные. Заполни пропуски медианой группируя ее по наиболее адекватной группировке.
#
# Где видно что существуют отрицательные в *days_employed*?</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Добавил описание и постарался описать свои действия
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b>
#
# Заметно лучше, но остались без внимания замечания:
#
# 1. Заполни пропуски медианой **группируя** ее по наиболее адекватной группировке.
#
# 2.Где видно что существуют отрицательные в *days_employed*?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# 1- Сделал групировку по труд стажу > 0 и типу - пенсионер
#
# 2- Сравнил данные столбца с 0
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера v3❌:</b>
#
# Из того что я вижу, ты взял медиану по пенсионерам и заполнил ею все пропуски *days_employed*. Не буду докапываться до логики. *days_employed - в задании нигде не используется, поэтому по желанию*.   Но в *total_income* - снова общая медиана.
#
# Смотри, важно заполнить пропущенные *total_income*
#
# Оценить *total_income* логично группируя медианами по *income_type*. По каждой категории *income_type*.
#
# Доделай пожалуйста

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Сгрупировал по 'total_income' и нашел мед значения 'total_income' для каждого типа
#
# Заполнил пустые значения, мед значением сотрудник, так как его большинство!
# </div>

# %% [markdown]
# ### Шаг 2.2 Проверка данных на аномалии и исправления.

# %% [markdown]
# Столбец **'children'**:

# %%
borrower_reliability['children'].value_counts() #количество уникальных совпадений в 'children'
# Out:
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64

# %% [markdown]
# **Аномалии в 'children':**
#     76 значений '20'
#     47 значений '-1'

# %%
borrower_reliability[borrower_reliability['children']==-1].head(10)
# Out:
#       children  days_employed  dob_years education  education_id  \
# 291         -1   -4417.703588         46   среднее             1
# 705         -1    -902.084528         50   среднее             1
# 742         -1   -3174.456205         57   среднее             1
# 800         -1  349987.852217         54   среднее             1
# 941         -1  365213.306266         57   Среднее             1
# 1363        -1   -1195.264956         55   СРЕДНЕЕ             1
# 1929        -1   -1461.303336         38   среднее             1
# 2073        -1   -2539.761232         42   среднее             1
# 3814        -1   -3045.290443         26   Среднее             1
# 4201        -1    -901.101738         41   среднее             1
#
#               family_status  family_status_id gender  income_type  debt  \
# 291        гражданский брак                 1      F    сотрудник     0
# 705         женат / замужем                 0      F  госслужащий     0
# 742         женат / замужем                 0      F    сотрудник     0
# 800   Не женат / не замужем                 4      F    пенсионер     0
# 941         женат / замужем                 0      F    пенсионер     0
# 1363        женат / замужем                 0      F    компаньон     0
# 1929  Не женат / не замужем                 4      M    сотрудник     0
# 2073              в разводе                 3      F    компаньон     0
# 3814       гражданский брак                 1      F  госслужащий     0
# 4201        женат / замужем                 0      F  госслужащий     0
#
#        total_income                          purpose
# 291   102816.346412           профильное образование
# 705   137882.899271          приобретение автомобиля
# 742    64268.044444       дополнительное образование
# 800    86293.724153       дополнительное образование
# 941   118514.486412     на покупку своего автомобиля
# 1363   69550.699692           профильное образование
# 1929  109121.569013                    покупка жилья
# 2073  162638.609373                    покупка жилья
# 3814  131892.785435            на проведение свадьбы
# 4201  226375.766751  операции со своей недвижимостью

# %%
borrower_reliability[borrower_reliability['children']==20].head(10)
# Out:
#       children  days_employed  dob_years education  education_id  \
# 606         20    -880.221113         21   среднее             1
# 720         20    -855.595512         44   среднее             1
# 1074        20   -3310.411598         56   среднее             1
# 2510        20   -2714.161249         59    высшее             0
# 2941        20   -2161.591519          0   среднее             1
# 3302        20  365213.306266         35   среднее             1
# 3396        20  365213.306266         56    высшее             0
# 3671        20    -913.161503         23   среднее             1
# 3697        20   -2907.910616         40   среднее             1
# 3735        20    -805.044438         26    высшее             0
#
#               family_status  family_status_id gender  income_type  debt  \
# 606         женат / замужем                 0      M    компаньон     0
# 720         женат / замужем                 0      F    компаньон     0
# 1074        женат / замужем                 0      F    сотрудник     1
# 2510         вдовец / вдова                 2      F    сотрудник     0
# 2941        женат / замужем                 0      F    сотрудник     0
# 3302  Не женат / не замужем                 4      F  госслужащий     0
# 3396        женат / замужем                 0      F    компаньон     0
# 3671  Не женат / не замужем                 4      F    сотрудник     0
# 3697       гражданский брак                 1      M    сотрудник     0
# 3735  Не женат / не замужем                 4      M    сотрудник     0
#
#        total_income                                purpose
# 606   145334.865002                          покупка жилья
# 720   112998.738649                   покупка недвижимости
# 1074  229518.537004                  получение образования
# 2510  264474.835577  операции с коммерческой недвижимостью
# 2941  199739.941398                  на покупку автомобиля
# 3302  150447.935283                 профильное образование
# 3396  172357.950966                     высшее образование
# 3671  101255.492076     на покупку подержанного автомобиля
# 3697  115380.694664     на покупку подержанного автомобиля
# 3735  137200.646181                           ремонт жилью

# %% [markdown]
# **Закономерности не прослеживаются в 'children'**
# Так как количество очень мало
# будем считать -1 == 1 и 20 == 2, что произошла опечатка данных

# %%
borrower_reliability.loc[borrower_reliability['children'] == 20, 'children'] = 2
borrower_reliability.loc[borrower_reliability['children'] == -1, 'children'] = 1
borrower_reliability['children'].value_counts()
# Out:
# 0    14149
# 1     4865
# 2     2131
# 3      330
# 4       41
# 5        9
# Name: children, dtype: int64

# %% [markdown]
# Столбец **'children'** приведен в порядок!

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Если непонятных данных не много, как здесь, рациональнее удалить эти строки.</div>

# %% [markdown]
# Столбец **'days_employed'**:

# %%
borrower_reliability['days_employed'].describe()
# Out:
# count     21525.000000
# mean      93564.994382
# std      161616.458135
# min      -18388.949901
# 25%       -2518.168900
# 50%        -982.531720
# 75%      333815.598166
# max      401755.400475
# Name: days_employed, dtype: float64

# %% [markdown]
# **Аномалии в 'days_employed'**:
#
# -max значение: **401755** дней (**1100 лет**).
# -mean значение: **60378** дней (**165 лет**).
# Будем считать что произошла ошибка данных при переносе в таблицу.
# так как данные не информативны удалим стобец<b>

# %%
del borrower_reliability['days_employed']
borrower_reliability.head(10)
# Out:
#    children  dob_years education  education_id     family_status  \
# 0         1         42    высшее             0   женат / замужем
# 1         1         36   среднее             1   женат / замужем
# 2         0         33   Среднее             1   женат / замужем
# 3         3         32   среднее             1   женат / замужем
# 4         0         53   среднее             1  гражданский брак
# 5         0         27    высшее             0  гражданский брак
# 6         0         43    высшее             0   женат / замужем
# 7         0         50   СРЕДНЕЕ             1   женат / замужем
# 8         2         35    ВЫСШЕЕ             0  гражданский брак
# 9         0         41   среднее             1   женат / замужем
#
#    family_status_id gender income_type  debt   total_income  \
# 0                 0      F   сотрудник     0  253875.639453
# 1                 0      F   сотрудник     0  112080.014102
# 2                 0      M   сотрудник     0  145885.952297
# 3                 0      M   сотрудник     0  267628.550329
# 4                 1      F   пенсионер     0  158616.077870
# 5                 1      M   компаньон     0  255763.565419
# 6                 0      F   компаньон     0  240525.971920
# 7                 0      M   сотрудник     0  135823.934197
# 8                 1      F   сотрудник     0   95856.832424
# 9                 0      M   сотрудник     0  144425.938277
#
#                       purpose
# 0               покупка жилья
# 1     приобретение автомобиля
# 2               покупка жилья
# 3  дополнительное образование
# 4             сыграть свадьбу
# 5               покупка жилья
# 6           операции с жильем
# 7                 образование
# 8       на проведение свадьбы
# 9     покупка жилья для семьи

# %% [markdown]
# Столбец **'days_employed'** удален

# %% [markdown]
# **Столбец 'education'**:

# %%
borrower_reliability['education'].value_counts()
# Out:
# среднее                13750
# высшее                  4718
# СРЕДНЕЕ                  772
# Среднее                  711
# неоконченное высшее      668
# ВЫСШЕЕ                   274
# Высшее                   268
# начальное                250
# Неоконченное высшее       47
# НЕОКОНЧЕННОЕ ВЫСШЕЕ       29
# НАЧАЛЬНОЕ                 17
# Начальное                 15
# ученая степень             4
# Ученая степень             1
# УЧЕНАЯ СТЕПЕНЬ             1
# Name: education, dtype: int64

# %% [markdown]
# Одни и теже категории с разными регистрами, приведем к одному регистру

# %%
borrower_reliability['education'] = borrower_reliability['education'].str.lower()

borrower_reliability['education'].value_counts(), borrower_reliability['education_id'].value_counts()
# Out:
# (среднее                15233
#  высшее                  5260
#  неоконченное высшее      744
#  начальное                282
#  ученая степень             6
#  Name: education, dtype: int64,
#  1    15233
#  0     5260
#  2      744
#  3      282
#  4        6
#  Name: education_id, dtype: int64)

# %% [markdown]
# **Столбец 'education'** приведен в порядок

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Сделано верно, молодец🔥</div>

# %% [markdown]
# Столбец **'dob_years'**:

# %%
borrower_reliability['dob_years'].value_counts().sort_index()
# Out:
# 0     101
# 19     14
# 20     51
# 21    111
# 22    183
# 23    254
# 24    264
# 25    357
# 26    408
# 27    493
# 28    503
# 29    545
# 30    540
# 31    560
# 32    510
# 33    581
# 34    603
# 35    617
# 36    555
# 37    537
# 38    598
# 39    573
# 40    609
# 41    607
# 42    597
# 43    513
# 44    547
# 45    497
# 46    475
# 47    480
# 48    538
# 49    508
# 50    514
# 51    448
# 52    484
# 53    459
# 54    479
# 55    443
# 56    487
# 57    460
# 58    461
# 59    444
# 60    377
# 61    355
# 62    352
# 63    269
# 64    265
# 65    194
# 66    183
# 67    167
# 68     99
# 69     85
# 70     65
# 71     58
# 72     33
# 73      8
# 74      6
# 75      1
# Name: dob_years, dtype: int64

# %%
borrower_reliability.loc[borrower_reliability['dob_years'] == 0, 'dob_years'] = borrower_reliability['dob_years'].mean() #заменим 0 на средний возраст
borrower_reliability['dob_years'] = borrower_reliability['dob_years'].astype('int') #заменим тип на Int
borrower_reliability['dob_years'].value_counts().sort_index() #проверим замену
# Out:
# 19     14
# 20     51
# 21    111
# 22    183
# 23    254
# 24    264
# 25    357
# 26    408
# 27    493
# 28    503
# 29    545
# 30    540
# 31    560
# 32    510
# 33    581
# 34    603
# 35    617
# 36    555
# 37    537
# 38    598
# 39    573
# 40    609
# 41    607
# 42    597
# 43    614
# 44    547
# 45    497
# 46    475
# 47    480
# 48    538
# 49    508
# 50    514
# 51    448
# 52    484
# 53    459
# 54    479
# 55    443
# 56    487
# 57    460
# 58    461
# 59    444
# 60    377
# 61    355
# 62    352
# 63    269
# 64    265
# 65    194
# 66    183
# 67    167
# 68     99
# 69     85
# 70     65
# 71     58
# 72     33
# 73      8
# 74      6
# 75      1
# Name: dob_years, dtype: int64

# %% [markdown]
# **Значение с возрастом-0 заменили на средний возраст**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Мне нравится, что ты проверяешь результат. Так держать!</div>

# %% [markdown]
# Столбец **'gender'**:

# %%
borrower_reliability['gender'].value_counts()
# Out:
# F      14236
# M       7288
# XNA        1
# Name: gender, dtype: int64

# %% [markdown]
# 1 значение **XNA=1**, изменим его на **F**, так как его большинство!

# %%
borrower_reliability.loc[borrower_reliability['gender'] == 'XNA', 'gender'] = 'F'
borrower_reliability['gender'].value_counts()
# Out:
# F    14237
# M     7288
# Name: gender, dtype: int64

# %% [markdown]
# Столбец **'gender'** приведен в порядок

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Опять же, лучше удалить строку с ошибкой</div>

# %% [markdown]
# Столбец **'income_type'**:

# %%
borrower_reliability['income_type'].value_counts()
# Out:
# сотрудник          11119
# компаньон           5085
# пенсионер           3856
# госслужащий         1459
# безработный            2
# предприниматель        2
# в декрете              1
# студент                1
# Name: income_type, dtype: int64

# %% [markdown]
# **'income_type'** в порядоке

# %%
borrower_reliability['debt'].value_counts()
# Out:
# 0    19784
# 1     1741
# Name: debt, dtype: int64

# %% [markdown]
# **'debt'** в порядоке

# %%
borrower_reliability['purpose'].value_counts()
# Out:
# свадьба                                   797
# на проведение свадьбы                     777
# сыграть свадьбу                           774
# операции с недвижимостью                  676
# покупка коммерческой недвижимости         664
# операции с жильем                         653
# покупка жилья для сдачи                   653
# операции с коммерческой недвижимостью     651
# жилье                                     647
# покупка жилья                             647
# покупка жилья для семьи                   641
# строительство собственной недвижимости    635
# недвижимость                              634
# операции со своей недвижимостью           630
# строительство жилой недвижимости          626
# покупка недвижимости                      624
# покупка своего жилья                      620
# строительство недвижимости                620
# ремонт жилью                              612
# покупка жилой недвижимости                607
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                495
# сделка с подержанным автомобилем          489
# свой автомобиль                           480
# на покупку подержанного автомобиля        479
# автомобили                                478
# на покупку автомобиля                     472
# дополнительное образование                462
# приобретение автомобиля                   462
# сделка с автомобилем                      455
# высшее образование                        453
# образование                               447
# получение дополнительного образования     447
# получение образования                     443
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     412
# Name: purpose, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> В целом, шаг мне нравится, делается все доказательно и с проверками. Молодец!</div>

# %% [markdown]
# ### Шаг 2.3. Изменение типов данных.

# %%
borrower_reliability['total_income'] = borrower_reliability['total_income'].astype('int')
borrower_reliability.info(), borrower_reliability.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   dob_years         21525 non-null  int64
#  2   education         21525 non-null  object
#  3   education_id      21525 non-null  int64
#  4   family_status     21525 non-null  object
#  5   family_status_id  21525 non-null  int64
#  6   gender            21525 non-null  object
#  7   income_type       21525 non-null  object
#  8   debt              21525 non-null  int64
#  9   total_income      21525 non-null  int64
#  10  purpose           21525 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 1.8+ MB
# (None,
#     children  dob_years education  education_id     family_status  \
#  0         1         42    высшее             0   женат / замужем
#  1         1         36   среднее             1   женат / замужем
#  2         0         33   среднее             1   женат / замужем
#  3         3         32   среднее             1   женат / замужем
#  4         0         53   среднее             1  гражданский брак
#
#     family_status_id gender income_type  debt  total_income  \
#  0                 0      F   сотрудник     0        253875
#  1                 0      F   сотрудник     0        112080
#  2                 0      M   сотрудник     0        145885
#  3                 0      M   сотрудник     0        267628
#  4                 1      F   пенсионер     0        158616
#
#                        purpose
#  0               покупка жилья
#  1     приобретение автомобиля
#  2               покупка жилья
#  3  дополнительное образование
#  4             сыграть свадьбу  )

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Хорошо. Но есть помарка в выводе</div>

# %% [markdown]
# ### Шаг 2.4. Удаление дубликатов.

# %%
borrower_reliability.duplicated().sum() #проверка кол-ва дубликатов
# Out:
# 71

# %%
borrower_reliability = borrower_reliability.drop_duplicates().reset_index(drop=True) #удаление дубликатов

# %%
borrower_reliability.duplicated().sum() # проверка, после удаления дубликатов
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Согласен😉</div>

# %% [markdown]
# ### Шаг 2.5. Формирование дополнительных датафреймов словарей, декомпозиция исходного датафрейма.

# %% [markdown]
# Создадим два новых датафрейма, в которых:
#
# Каждому уникальному значению из education соответствует уникальное значение **education_id** — в первом;
# Каждому уникальному значению из family_status соответствует уникальное значение **family_status_id** — во втором.

# %%
education_id = borrower_reliability[['education', 'education_id']] #создаем словарь education_id

education_id = education_id .drop_duplicates().reset_index(drop=True) # удаляем дубликаты из словаря

education_id
# Out:
#              education  education_id
# 0               высшее             0
# 1              среднее             1
# 2  неоконченное высшее             2
# 3            начальное             3
# 4       ученая степень             4

# %%
family_status_id = borrower_reliability[['family_status', 'family_status_id']] #создаем словарь family_status_id

family_status_id = family_status_id.drop_duplicates().reset_index(drop=True) # удаляем дубликаты из словаря


family_status_id
# Out:
#            family_status  family_status_id
# 0        женат / замужем                 0
# 1       гражданский брак                 1
# 2         вдовец / вдова                 2
# 3              в разводе                 3
# 4  Не женат / не замужем                 4

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b> Как видишь, есть что исправить. Перед сдачей всегда перезапускай весь проект!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Поправил вывод, код работает
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера v2✅:</b> Отлично!🔥</div>

# %% [markdown]
# Удалим столбы **['education']** и **['family_status']** и проверим

# %%
del borrower_reliability['education'] #удаляем стобец 'education'
del borrower_reliability['family_status'] #удаляем столбец 'family_status'


borrower_reliability.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21454 entries, 0 to 21453
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21454 non-null  int64
#  1   dob_years         21454 non-null  int64
#  2   education_id      21454 non-null  int64
#  3   family_status_id  21454 non-null  int64
#  4   gender            21454 non-null  object
#  5   income_type       21454 non-null  object
#  6   debt              21454 non-null  int64
#  7   total_income      21454 non-null  int64
#  8   purpose           21454 non-null  object
# dtypes: int64(6), object(3)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Шаг 2.6. Категоризация дохода.

# %% [markdown]
# На основании диапазонов, создадим новый столбец **total_income_category**

# %%
def total_income_category(total_income):
    if total_income <= 30000:
        return 'E'
    elif total_income <= 50000:
        return 'D'
    elif total_income <= 200000:
        return 'C'
    elif total_income <= 1000000:
        return 'B'
    return 'A'


borrower_reliability['total_income_category'] = borrower_reliability['total_income'].apply(total_income_category)
borrower_reliability.head()
# Out:
#    children  dob_years  education_id  family_status_id gender income_type  \
# 0         1         42             0                 0      F   сотрудник
# 1         1         36             1                 0      F   сотрудник
# 2         0         33             1                 0      M   сотрудник
# 3         3         32             1                 0      M   сотрудник
# 4         0         53             1                 1      F   пенсионер
#
#    debt  total_income                     purpose total_income_category
# 0     0        253875               покупка жилья                     B
# 1     0        112080     приобретение автомобиля                     C
# 2     0        145885               покупка жилья                     C
# 3     0        267628  дополнительное образование                     B
# 4     0        158616             сыграть свадьбу                     C

# %%
borrower_reliability['total_income_category'].value_counts()
# Out:
# C    16015
# B     5042
# D      350
# A       25
# E       22
# Name: total_income_category, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b> Отлично!🔥</div>

# %% [markdown]
# ### Шаг 2.7. Категоризация целей кредита.

# %%
borrower_reliability['purpose'].value_counts()
# Out:
# свадьба                                   791
# на проведение свадьбы                     768
# сыграть свадьбу                           765
# операции с недвижимостью                  675
# покупка коммерческой недвижимости         661
# операции с жильем                         652
# покупка жилья для сдачи                   651
# операции с коммерческой недвижимостью     650
# жилье                                     646
# покупка жилья                             646
# покупка жилья для семьи                   638
# строительство собственной недвижимости    635
# недвижимость                              633
# операции со своей недвижимостью           627
# строительство жилой недвижимости          624
# покупка недвижимости                      621
# покупка своего жилья                      620
# строительство недвижимости                619
# ремонт жилью                              607
# покупка жилой недвижимости                606
# на покупку своего автомобиля              505
# заняться высшим образованием              496
# автомобиль                                494
# сделка с подержанным автомобилем          486
# автомобили                                478
# свой автомобиль                           478
# на покупку подержанного автомобиля        478
# на покупку автомобиля                     471
# приобретение автомобиля                   461
# дополнительное образование                460
# сделка с автомобилем                      455
# высшее образование                        452
# образование                               447
# получение дополнительного образования     446
# получение образования                     442
# профильное образование                    436
# получение высшего образования             426
# заняться образованием                     408
# Name: purpose, dtype: int64

# %%
def purpose_category(i):
    if "автомобил" in i:
        return 'операции с автомобилем'
    elif 'недвиж' in i or 'жиль' in i:
        return 'операции с недвижимостью'
    elif 'свадьб' in i:
        return 'проведение свадьбы'
    else:
        return 'получение образования'
    
borrower_reliability['purpose_category']=borrower_reliability['purpose'].apply(purpose_category) 
borrower_reliability.head()
# Out:
#    children  dob_years  education_id  family_status_id gender income_type  \
# 0         1         42             0                 0      F   сотрудник
# 1         1         36             1                 0      F   сотрудник
# 2         0         33             1                 0      M   сотрудник
# 3         3         32             1                 0      M   сотрудник
# 4         0         53             1                 1      F   пенсионер
#
#    debt  total_income                     purpose total_income_category  \
# 0     0        253875               покупка жилья                     B
# 1     0        112080     приобретение автомобиля                     C
# 2     0        145885               покупка жилья                     C
# 3     0        267628  дополнительное образование                     B
# 4     0        158616             сыграть свадьбу                     C
#
#            purpose_category
# 0  операции с недвижимостью
# 1    операции с автомобилем
# 2  операции с недвижимостью
# 3     получение образования
# 4        проведение свадьбы

# %%
borrower_reliability['purpose_category'].value_counts()
# Out:
# операции с недвижимостью    10811
# операции с автомобилем       4306
# получение образования        4013
# проведение свадьбы           2324
# Name: purpose_category, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b>
#
# У тебя все, что не найдено маркируется как `операции с недвижимостью`. Это может искажать данные!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Поправил функцию: сделал поиск по "недвиж" и "жиль"
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера v2✅:</b> Годится!</div>

# %% [markdown]
# ### Ответы на вопросы.

# %% [markdown]
# ##### Вопрос 1: Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %% [markdown]
# Сформирует **сводную таблицу** которая покажет количество **задолженности ('debt')** по количеству детей:

# %%
data_pivot_children = borrower_reliability.pivot_table(index=['children'], values=['debt'], aggfunc='sum')
data_pivot_children.columns = ['Задолженность']
data_pivot_children
# Out:
#           Задолженность
# children
# 0                  1063
# 1                   445
# 2                   202
# 3                    27
# 4                     4
# 5                     0

# %%
def analyse_debt(column_list):
    analyse_table = borrower_reliability.groupby(column_list).agg({'debt':['sum', 'count']})
    analyse_table[('debt', '% не выплат')] = analyse_table[('debt', 'sum')] / analyse_table[('debt', 'count')]*100
    return analyse_table

analyse_debt(['children'])
# Out:
#           debt
#            sum  count % не выплат
# children
# 0         1063  14091    7.543822
# 1          445   4855    9.165808
# 2          202   2128    9.492481
# 3           27    330    8.181818
# 4            4     41    9.756098
# 5            0      9    0.000000

# %% [markdown]
# ##### Вывод 1:
# Из полученных данных видно, что больше всего берут кредиты те у кого нет детей, количество
# не выплат у них тоже выше остальных. Но процент не выплат у данной категории самый низкий на уровне 7,5%
#
# Далее идут люди у которых 1 ребенок, процент не выплат у них уже выше и достигает 9,15%
#
# У кого 2 ребенка высокий процент не выплаты кредита - 9,48% (почти как и в ситуации с 4 детьми), хотя по поддержке государства за второго ребенка семьи получают материнский капиталл.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:
#
# Не находишь противоречия? : `Люди у которых нет детей имеют больше просроченных кредитов.`
# и `С дугой стороны доля невыплат меньше всего у тех укого нет детей - 7,5%.`

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Заменил вывод на 1 вопрос
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера v2✅:</b> Ок!👍</div>

# %% [markdown]
# ##### Вопрос 2: Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
data_pivot_children = borrower_reliability.pivot_table(index=['family_status_id'], values=['debt'], aggfunc='sum')
analyse_debt(['family_status_id'])
# Out:
#                  debt
#                   sum  count % не выплат
# family_status_id
# 0                 931  12339    7.545182
# 1                 388   4151    9.347145
# 2                  63    959    6.569343
# 3                  85   1195    7.112971
# 4                 274   2810    9.750890

# %% [markdown]
# ##### Вывод 2:
# Из полученных данных видно, что больше всего берут кредиты **0-женатые/замужние**, количество
# не выплат у них тоже выше остальных. Но процент не выплат у данной категории низкий на уровне 7,5%
# Ниже процент не выплат у **3-в разводе** и равен 7,1%
#
# Самый низкий процент не выплат имеют **2-вдовец/вдова** - на уровне 6,6%
#
# Категории **1-гражданский брак** и **4-не женат/не замужем** имеют процент не выплат в районе 9.3-9.8%

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌: </b>
# Боюсь ты запутался в индексах. Выведи пожалуйста именованные категории и подтверди выводы. Лучше модернизировать твою функцию analyse_debt()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Заменил вывод на 2 вопрос
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>Комментарий ревьюера v2✅:</b> Было-бы идеально, если бы ты вывел имена категорий в табличку! Формулируй более очевидные выводы. Напимер здесь основной вывод, что чаще просрочка у тех, кто не состоял в браке.</div>

# %% [markdown]
# ##### Вопрос 3: Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
analyse_debt(['total_income_category'])
# Out:
#                        debt
#                         sum  count % не выплат
# total_income_category
# A                         2     25    8.000000
# B                       356   5042    7.060690
# C                      1360  16015    8.492039
# D                        21    350    6.000000
# E                         2     22    9.090909

# %% [markdown]
# ##### Вывод 3:
#
# Самый большая часть которая берет кредиты это люди с зп **"С"(50-200 тыс)**. Она практически в 3 раза больше всех остальные вместе взятых категорий. Процент не выплат составляет при этом 8,5%
#
# На 2 месте люди с доходом **"B"(200-1000тыс)**, доля кредитов значительно меньше категории С. Процент не выплат составляет 7,1%
#
# Самый низкий процент не выплат имеют люди с зп **"D"(30-50тыс)** он равен 6%
#
# Люди с доходом свыше 1млн и ниже 30тыс, особо не берут кредиты, но при этом имеют 8% и 9% соответственно

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий ревьюера⚠️:</b> Мы не можем здесь опираться на распределение. Я бы сделал более очевидные выводы.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Попробовал переписать вывод
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера v2✅:</b> Твои выводы больше похожи на словесное описание таблиц😉. По возможности делай заключения на основании увиденного</div>

# %% [markdown]
# ##### Вопрос 4: Как разные цели кредита влияют на его возврат в срок?

# %%
analyse_debt(['purpose_category'])
# Out:
#                          debt
#                           sum  count % не выплат
# purpose_category
# операции с автомобилем    403   4306    9.359034
# операции с недвижимостью  782  10811    7.233373
# получение образования     370   4013    9.220035
# проведение свадьбы        186   2324    8.003442

# %% [markdown]
# ##### Вывод 4:
#
# Больше всего кредитов имеет категория **"операции с недвижимостью"**, но зато доля просрочек по категории 7,2% - самая низкая.
#
# В категориях **"операции с автомобилем"** и **"получение образования"** число взятых кредитов, а также процент невыплат примерно одинаков и составляет около 9,2-9.3%.
#
# Не выплат в более мелкой категории **"проведение свадьбы"** и доля просрочек 7,9% (всего на 0,7% выше чем **"недвижимость"**) - невысоко по сравнению **"операции с автомобилем"** и **"получение образования"**.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# 2.7 пункт поправил
# Заменил вывод на 4 вопрос
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера❌:</b>
#
# Обрати внимание на навигацию Ответов на Вопросы. Заголовки потерялись.

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Постарался поправить
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий ревьюера v2❌:</b>
#
# Расставь #-и в начале заголовков и проверь результат в меню -> Navigate

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Разобрался! Сразу не понял про навигацию...
# Вопросы и выводы теперь есть в Навигации и соответствуют разделам!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера v3✅:</b> Отлично!

# %% [markdown]
# ## Общий вывод:

# %% [markdown]
# В ходе процесса мы проанализировали данные.
#
# При предобработке данных было удалено около 1% некорректных строк и 1 некорректный столбец(который для поставленных задач не был необходим).
#
# Поменяли в 1 столбце типы - для лучшей наглядности и более быстрой обработки. Удалили дубликаты.
#
# Для одного столбца сделали категоризацию.
#
# После подготовки данных, сделали сводные таблицы (ипользовали функцию) и ответили на все 4 поставленных вопроса.
#
# Были выявили закономерности в просрочках по кредитам(где-то ярко выраженные, а где-то нет).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b>
#
# Мне очень понравилась твоя работа. На шаге `Проверка данных на аномалии и исправления` Ты подробно разбираешься в деталях, для будущего аналитика это очень важная черта😊
#
# Проект еще нужно немного доработать, а именно:
# - поправить навигацию.
# - исправить замечания по модификации данных
# - поработать с выводами ответов на вопросы когда данные станут более чистыми
#
# Остальные замечания оставляю на твое усмотрение😉
#
# Жду твою работу на повторное ревью.
#
# [Тут есть полезные приемы Markdown](https://paulradzkov.com/2014/markdown_cheatsheet/)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера✅:</b>
#
# Извини за опоздание ревью.
#
# У тебя все получается!😉
#
# Исправь критические замечания по шагу 2.1, Заголовки в Ответах на вопросы и я приму тр

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# пункт 2.1 полностью переделал, сгрупировав!
#
# Навигацию поправил!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера v3✅:</b>
#
# Отлично навигацию принял.
#
# Добей 2.1👍

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Пункт 2.1 переделал, сгрупировав!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера v4✅:</b>
#
# Жду решения замечания по 2.1
#
# Я понимаю, что эта задача возможно достала, но без этого трудно двигаться дальше. Успеха!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
# Пункт 2.1 переделал...!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера v5✅:</b>
#
# И снова жду решения замечания по 2.1
#
# Удачи!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b>
#
# Прошу прощения...
#
# Пункт 2.1 переделал!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий ревьюера v6✅:</b>
#
# Принято! 👍👍👍
#
# Идеально если бы в 2.1 не было прямых ссылок на типы дохода.😉
#
# Желаю дальнейших успехов!
